# %%
rows = 6

for i in range(1, rows+1):
    for j in range(rows - i):
        print(" ", end="")
    for k in range(2 * i - 1):
        print("*", end="")
    print()
# Out:
#      *
#     ***
#    *****
#   *******
#  *********
# ***********

# %%
users = ["admin", "guest", "user", "guest"]

for user in users:
    if user == "guest":
        users.remove(user)

print(users)
# Out:
# ['admin', 'user']
